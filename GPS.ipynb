# %%
import geocoder  
g = geocoder.google('Mountain View, CA')
g.latlng
#(37.3860517, -122.0838511)
# Out:
# C:\Anaconda2\lib\site-packages\requests\__init__.py:83: RequestsDependencyWarning: Old version of cryptography ([1, 3]) may cause slowdown.
#   warnings.warn(warning, RequestsDependencyWarning)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-1-80a6a99fb112> in <module>()
#       1 import geocoder
#       2 g = geocoder.google('Mountain View, CA')
# ----> 3 g.latlng
#       4 #(37.3860517, -122.0838511)
#
# C:\Anaconda2\lib\site-packages\geocoder\base.pyc in __getattr__(self, name)
#     917         """
#     918         if not self.ok:
# --> 919             raise ValueError(self.status)
#     920
#     921         if self.current_result is None:
#
# ValueError: ERROR - No results found

# %%
>>> import geocoder

#41.83361111111111  -87.61694444444444
>>> g = geocoder.osm([41.83361111111111, -87.61694444444444], method='reverse')
>>> print g.json['city'] # Prints Edmonton
# Out:
# Chicago

# %%
#Step B
from math import sin, cos, sqrt, atan2, radians

# approximate radius of earth in km
R = 6373.0

lat1 = radians(52.2296756)
lon1 = radians(21.0122287)
lat2 = radians(52.406374)
lon2 = radians(16.9251681)

dlon = lon2 - lon1
dlat = lat2 - lat1

a = sin(dlat / 2)**2 + cos(lat1) * cos(lat2) * sin(dlon / 2)**2
c = 2 * atan2(sqrt(a), sqrt(1 - a))

distance = R * c

print("Result:", distance)
print("Should be:", 278.546, "km")
# Out:
# ('Result:', 278.54558935106695)
# ('Should be:', 278.546, 'km')

# %%
#Step B
from math import sin, cos, sqrt, atan2, radians

# approximate radius of earth in km
R = 6373.0

lat1 = radians(37.3860517)
lon1 = radians(-122.0838511)
lat2 = radians(41.83361111111111)
lon2 = radians(-87.61694444444444)

dlon = lon2 - lon1
dlat = lat2 - lat1

a = sin(dlat / 2)**2 + cos(lat1) * cos(lat2) * sin(dlon / 2)**2
c = 2 * atan2(sqrt(a), sqrt(1 - a))

distance = R * c

print("Result:", distance)
print("Should be:", 278.546, "km")
# Out:
# ('Result:', 2974.2199568893916)
# ('Should be:', 278.546, 'km')

# %%
import pandas as pd

# %%
pwd
# Out:
# u'C:\\Users\\michael.dong'

# %%
cd 'F:\Shared\MichaelDong'
# Out:
# F:\Shared\MichaelDong

# %%
df = pd.read_csv('PROD_DATA_828.csv')

# %%
df
# Out:
#        created_yr_mth  disbursed_yr_mth origination_channel  disbursed_ind  \
# 0              201601               NaN              mobile              0
# 1              201601               NaN               STORE              0
# 2              201601          201601.0              mobile              1
# 3              201601          201601.0              mobile              1
# 4              201601          201601.0              mobile              1
# 5              201601          201601.0              mobile              1
# 6              201601          201601.0              mobile              1
# 7              201601          201601.0              mobile              1
# 8              201601          201601.0              mobile              1
# 9              201601          201601.0              mobile              1
# 10             201601          201601.0              mobile              1
# ...

# %%
df['new'] =
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-48-517a3f4ac2b0> in <module>()
# ----> 1 dff = pd.DataFrame(list[1,2,3,4,5,6,7,8])
#
# TypeError: 'type' object has no attribute '__getitem__'

# %%
for i in range(len(df['tot_apps'])):
    R = 6373.0

    lat1 = radians(df['tot_apps'][i])
    lon1 = radians(df['tot_apps'][i])
    lat2 = radians(df['tot_apps'][i])
    lon2 = radians(df['tot_apps'][i])

    dlon = lon2 - lon1
    dlat = lat2 - lat1

    a = sin(dlat / 2)**2 + cos(lat1) * cos(lat2) * sin(dlon / 2)**2
    c = 2 * atan2(sqrt(a), sqrt(1 - a))

    distance = R * c

    print("Result:", distance)
    print("Should be:", 278.546, "km")
# Out:
# ('Result:', 0.0)
# ('Should be:', 278.546, 'km')
# ('Result:', 0.0)
# ('Should be:', 278.546, 'km')
# ('Result:', 0.0)
# ('Should be:', 278.546, 'km')
# ('Result:', 0.0)
# ('Should be:', 278.546, 'km')
# ('Result:', 0.0)
# ('Should be:', 278.546, 'km')
# ('Result:', 0.0)
# ('Should be:', 278.546, 'km')
# ('Result:', 0.0)
# ('Should be:', 278.546, 'km')
# ('Result:', 0.0)
# ('Should be:', 278.546, 'km')
# ('Result:', 0.0)
# ('Should be:', 278.546, 'km')
# ('Result:', 0.0)
# ('Should be:', 278.546, 'km')
# ('Result:', 0.0)
# ('Should be:', 278.546, 'km')
# ('Result:', 0.0)
# ('Should be:', 278.546, 'km')
# ('Result:', 0.0)
# ('Should be:', 278.546, 'km')
# ('Result:', 0.0)
# ('Should be:', 278.546, 'km')
# ('Result:', 0.0)
# ('Should be:', 278.546, 'km')
# ('Result:', 0.0)
# ('Should be:', 278.546, 'km')
# ('Result:', 0.0)
# ('Should be:', 278.546, 'km')
# ('Result:', 0.0)
# ('Should be:', 278.546, 'km')
# ('Result:', 0.0)
# ('Should be:', 278.546, 'km')
# ('Result:', 0.0)
# ...

# %%
list_city = ['Chicago, IL','Mountain View, CA']

# %%
for i in range(len(list_city)):
    g = geocoder.google(i)
    print g.latlng
# Out:
# [44.200797, 24.5022981]
# [44.473235, -73.217882]

# %%
import geocoder  
g = geocoder.google('Mountain View, CA')
g.latlng
#(37.3860517, -122.0838511)
